# %%
import pandas as pd

# %%
df = pd.read_json("./result.json")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 4 columns):
# commits      265 non-null object
# priece       265 non-null object
# title        265 non-null object
# total_num    265 non-null object
# dtypes: object(4)
# memory usage: 8.4+ KB

# %%
df
# Out:
#                 commits   priece  \
# 0    4.2 out of 5 stars   $26.40
# 1    4.6 out of 5 stars   $39.95
# 2    4.0 out of 5 stars   $23.99
# 3    4.4 out of 5 stars   $39.95
# 4    4.5 out of 5 stars   $16.83
# 5    4.8 out of 5 stars   $29.95
# 6    4.5 out of 5 stars   $17.99
# 7    4.4 out of 5 stars   $29.95
# 8    4.5 out of 5 stars   $29.26
# 9    4.2 out of 5 stars   $37.49
# 10   4.9 out of 5 stars   $63.99
# 11   4.9 out of 5 stars    $0.00
# 12   5.0 out of 5 stars   $14.95
# 13   4.8 out of 5 stars    $0.00
# 14   4.6 out of 5 stars   $23.74
# 15   3.6 out of 5 stars   $24.99
# 16   4.7 out of 5 stars    $0.00
# 17   4.8 out of 5 stars   $14.95
# 18   4.3 out of 5 stars    $2.99
# 19   4.6 out of 5 stars   $17.97
# 20   4.3 out of 5 stars   $17.97
# 21   4.4 out of 5 stars   $22.00
# 22   4.3 out of 5 stars   $29.99
# 23   4.5 out of 5 stars    $4.99
# 24   5.0 out of 5 stars   $29.99
# 25   4.3 out of 5 stars   $31.37
# 26   4.7 out of 5 stars   $59.99
# ...

# %% [markdown]
# Transform the object to num

# %%
df = df.replace(',',)
